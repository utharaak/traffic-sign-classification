# %% [markdown]
# # 18CSC402 Deep Learning
# CB.SC.I5DAS18044
# Uthara Koliyot

# %% [markdown]
# # CODE TO CLASSIFY TRAFFIC SIGNS USING LE-NET ARCHITECTURE IN KERAS

# %% [markdown]
# # PROBLEM STATEMENT

# %% [markdown]
# - In this case study, I am trying to train a Deep Network Model to classify traffic sign images
# - The dataset contains 43 different classes of images.
# - Classes are as listed below:
#
#     - ( 0, b'Speed limit (20km/h)') ( 1, b'Speed limit (30km/h)')
#     - ( 2, b'Speed limit (50km/h)') ( 3, b'Speed limit (60km/h)')
#     - ( 4, b'Speed limit (70km/h)') ( 5, b'Speed limit (80km/h)')
#     - ( 6, b'End of speed limit (80km/h)') ( 7, b'Speed limit (100km/h)')
#     - ( 8, b'Speed limit (120km/h)') ( 9, b'No passing')
#     - (10, b'No passing for vehicles over 3.5 metric tons')
#     - (11, b'Right-of-way at the next intersection') (12, b'Priority road')
#     - (13, b'Yield') (14, b'Stop') (15, b'No vehicles')
#     - (16, b'Vehicles over 3.5 metric tons prohibited') (17, b'No entry')
#     - (18, b'General caution') (19, b'Dangerous curve to the left')
#     - (20, b'Dangerous curve to the right') (21, b'Double curve')
#     - (22, b'Bumpy road') (23, b'Slippery road')
#     - (24, b'Road narrows on the right') (25, b'Road work')
#     - (26, b'Traffic signals') (27, b'Pedestrians') (28, b'Children crossing')
#     - (29, b'Bicycles crossing') (30, b'Beware of ice/snow')
#     - (31, b'Wild animals crossing')
#     - (32, b'End of all speed and passing limits') (33, b'Turn right ahead')
#     - (34, b'Turn left ahead') (35, b'Ahead only') (36, b'Go straight or right')
#     - (37, b'Go straight or left') (38, b'Keep right') (39, b'Keep left')
#     - (40, b'Roundabout mandatory') (41, b'End of no passing')
#     - (42, b'End of no passing by vehicles over 3.5 metric tons')
#
# - The network used is called Le-Net that was presented by Yann LeCun
# http://yann.lecun.com/exdb/publis/pdf/lecun-01a.pdf

# %% [markdown]
# # STEP 1: IMPORT LIBRARIES AND DATASET

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pickle
import seaborn as sns
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt # 
import random

# %%
with open("/content/drive/MyDrive/Project 5/traffic-signs-data/train.p", mode='rb') as training_data:
    train = pickle.load(training_data)
with open("/content/drive/MyDrive/Project 5/traffic-signs-data/valid.p", mode='rb') as validation_data:
    valid = pickle.load(validation_data)
with open("/content/drive/MyDrive/Project 5/traffic-signs-data/test.p", mode='rb') as testing_data:
    test = pickle.load(testing_data)

# %%
X_train, y_train = train['features'], train['labels']
X_validation, y_validation = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %%
X_train.shape
# Out:
# (34799, 32, 32, 3)

# %%
y_train.shape
# Out:
# (34799,)

# %% [markdown]
# # STEP 2: IMAGE EXPLORATION

# %%
i = 1001
plt.imshow(X_train[i]) 
y_train[i]
# Out:
# 36

# %% [markdown]
# # STEP 3: DATA PEPARATION

# %%
## Shuffle the dataset 
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_train, y_train)

# %%
X_train_gray = np.sum(X_train/3, axis=3, keepdims=True)
X_test_gray  = np.sum(X_test/3, axis=3, keepdims=True)
X_validation_gray  = np.sum(X_validation/3, axis=3, keepdims=True)

# %%
X_train_gray_norm = (X_train_gray - 128)/128 
X_test_gray_norm = (X_test_gray - 128)/128
X_validation_gray_norm = (X_validation_gray - 128)/128

# %%
X_train_gray.shape
# Out:
# (34799, 32, 32, 1)

# %%
i = 610
plt.imshow(X_train_gray[i].squeeze(), cmap='gray')
plt.figure()
plt.imshow(X_train[i])

# %% [markdown]
# # STEP 4: MODEL TRAINING

# %% [markdown]
# The model consists of the following layers:
#
# - STEP 1: THE FIRST CONVOLUTIONAL LAYER #1
#     - Input = 32x32x1
#     - Output = 28x28x6
#     - Output = (Input-filter+1)/Stride* => (32-5+1)/1=28
#     - Used a 5x5 Filter with input depth of 3 and output depth of 6
#     - Apply a RELU Activation function to the output
#     - pooling for input, Input = 28x28x6 and Output = 14x14x6
#
#
#
# - STEP 2: THE SECOND CONVOLUTIONAL LAYER #2
#     - Input = 14x14x6
#     - Output = 10x10x16
#     - Layer 2: Convolutional layer with Output = 10x10x16
#     - Output = (Input-filter+1)/strides => 10 = 14-5+1/1
#     - Apply a RELU Activation function to the output
#     - Pooling with Input = 10x10x16 and Output = 5x5x16
#
# - STEP 3: FLATTENING THE NETWORK
#     - Flatten the network with Input = 5x5x16 and Output = 400
#
# - STEP 4: FULLY CONNECTED LAYER
#     - Layer 3: Fully Connected layer with Input = 400 and Output = 120
#     - Apply a RELU Activation function to the output
#
# - STEP 5: ANOTHER FULLY CONNECTED LAYER
#     - Layer 4: Fully Connected Layer with Input = 120 and Output = 84
#     - Apply a RELU Activation function to the output
#
# - STEP 6: FULLY CONNECTED LAYER
#     - Layer 5: Fully Connected layer with Input = 84 and Output = 43

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from keras.callbacks import TensorBoard

from sklearn.model_selection import train_test_split

# %%
image_shape = X_train_gray[i].shape

# %% [markdown]
# # Model 2

# %%
cnn_model = Sequential()

cnn_model.add(Conv2D(filters=24, kernel_size=(5, 5), activation='relu', input_shape=(32,32,1)))
cnn_model.add(AveragePooling2D())

cnn_model.add(Conv2D(filters=64, kernel_size=(5, 5), activation='relu'))
cnn_model.add(AveragePooling2D())

cnn_model.add(Flatten())

cnn_model.add(Dense(units=480, activation='relu'))

cnn_model.add(Dense(units=120, activation='relu'))

cnn_model.add(Dense(units=43, activation = 'softmax'))

# %%
cnn_model.compile(loss ='sparse_categorical_crossentropy', optimizer=Adam(lr=0.005),metrics =['accuracy'])

# %%
history = cnn_model.fit(X_train_gray_norm,
                        y_train,
                        batch_size=500,
                        epochs=100,
                        verbose=1,
                        validation_data = (X_validation_gray_norm,y_validation))
# Out:
# Epoch 1/100
# 70/70 [==============================] - 36s 514ms/step - loss: 2.5339 - accuracy: 0.3136 - val_loss: 1.2587 - val_accuracy: 0.6256
# Epoch 2/100
# 70/70 [==============================] - 36s 513ms/step - loss: 0.6147 - accuracy: 0.8138 - val_loss: 0.5946 - val_accuracy: 0.8184
# Epoch 3/100
# 70/70 [==============================] - 36s 514ms/step - loss: 0.2864 - accuracy: 0.9180 - val_loss: 0.4497 - val_accuracy: 0.8732
# Epoch 4/100
# 70/70 [==============================] - 36s 514ms/step - loss: 0.1649 - accuracy: 0.9554 - val_loss: 0.4320 - val_accuracy: 0.8864
# Epoch 5/100
# 70/70 [==============================] - 36s 515ms/step - loss: 0.1087 - accuracy: 0.9703 - val_loss: 0.4520 - val_accuracy: 0.8934
# Epoch 6/100
# 70/70 [==============================] - 36s 514ms/step - loss: 0.0768 - accuracy: 0.9797 - val_loss: 0.4232 - val_accuracy: 0.9007
# Epoch 7/100
# 70/70 [==============================] - 36s 515ms/step - loss: 0.0611 - accuracy: 0.9832 - val_loss: 0.6054 - val_accuracy: 0.8875
# Epoch 8/100
# 70/70 [==============================] - 36s 515ms/step - loss: 0.0507 - accuracy: 0.9850 - val_loss: 0.4121 - val_accuracy: 0.9109
# Epoch 9/100
# 70/70 [==============================] - 36s 517ms/step - loss: 0.0402 - accuracy: 0.9886 - val_loss: 0.4612 - val_accuracy: 0.9109
# Epoch 10/100
# 70/70 [==============================] - 36s 517ms/step - loss: 0.0276 - accuracy: 0.9920 - val_loss: 0.4691 - val_accuracy: 0.9118
# Epoch 11/100
# 70/70 [==============================] - 36s 518ms/step - loss: 0.0344 - accuracy: 0.9898 - val_loss: 0.5093 - val_accuracy: 0.8989
# Epoch 12/100
# 70/70 [==============================] - 36s 517ms/step - loss: 0.0275 - accuracy: 0.9908 - val_loss: 0.5501 - val_accuracy: 0.9018
# Epoch 13/100
# 70/70 [==============================] - 36s 516ms/step - loss: 0.
100
# 70/70 [==============================] - 36s 515ms/step - loss: 0.0084 - accuracy: 0.9979 - val_loss: 0.8036 - val_accuracy: 0.9213
# Epoch 80/100
# 70/70 [==============================] - 36s 515ms/step - loss: 0.0108 - accuracy: 0.9972 - val_loss: 0.7917 - val_accuracy: 0.9243
# Epoch 81/100
# 70/70 [==============================] - 36s 517ms/step - loss: 0.0035 - accuracy: 0.9990 - val_loss: 0.6602 - val_accuracy: 0.9472
# Epoch 82/100
# 70/70 [==============================] - 36s 515ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.5687 - val_accuracy: 0.9542
# Epoch 83/100
# 70/70 [==============================] - 36s 516ms/step - loss: 0.0063 - accuracy: 0.9990 - val_loss: 0.6110 - val_accuracy: 0.9413
# Epoch 84/100
# 70/70 [==============================] - 36s 514ms/step - loss: 0.0154 - accuracy: 0.9966 - val_loss: 0.9429 - val_accuracy: 0.9279
# Epoch 85/100
# 70/70 [==============================] - 36s 516ms/step - loss: 0.0230 - accuracy: 0.9949 - val_loss: 0.7532 - val_accuracy: 0.9379
# Epoch 86/100
# 70/70 [==============================] - 36s 514ms/step - loss: 0.0183 - accuracy: 0.9961 - val_loss: 1.2021 - val_accuracy: 0.9073
# Epoch 87/100
# 70/70 [==============================] - 36s 514ms/step - loss: 0.0210 - accuracy: 0.9950 - val_loss: 1.1490 - val_accuracy: 0.9138
# Epoch 88/100
# 70/70 [==============================] - 36s 515ms/step - loss: 0.0158 - accuracy: 0.9957 - val_loss: 0.8537 - val_accuracy: 0.9290
# Epoch 89/100
# 70/70 [==============================] - 36s 515ms/step - loss: 0.0104 - accuracy: 0.9974 - val_loss: 0.6834 - val_accuracy: 0.9392
# Epoch 90/100
# 70/70 [==============================] - 36s 516ms/step - loss: 0.0085 - accuracy: 0.9982 - val_loss: 0.7232 - val_accuracy: 0.9363
# Epoch 91/100
# 70/70 [==============================] - 36s 514ms/step - loss: 0.0064 - accuracy: 0.9981 - val_loss: 0.6656 - val_accuracy: 0.9370
# Epoch 92/100
# 70/70 [==============================] - 36s 514ms/step - loss: 0.0102 - accuracy: 0.9974 - val_loss: 1.1690 - val_accuracy: 0.9156
# Epoch 93/100
# 70/70 [==============================] - 36s 513ms/step - loss: 0.0095 - accuracy: 0.9977 - val_loss: 0.9602 - val_accuracy: 0.9224
# Epoch 94/100
# 70/70 [==============================] - 36s 514ms/step - loss: 0.0090 - accuracy: 0.9978 - val_loss: 0.8506 - val_accuracy: 0.9329
# Epoch 95/100
# 70/70 [==============================] - 36s 514ms/step - loss: 0.0092 - accuracy: 0.9979 - val_loss: 0.8132 - val_accuracy: 0.9399
# Epoch 96/100
# 70/70 [==============================] - 36s 515ms/step - loss: 0.0108 - accuracy: 0.9973 - val_loss: 0.9788 - val_accuracy: 0.9256
# Epoch 97/100
# 70/70 [==============================] - 36s 516ms/step - loss: 0.0098 - accuracy: 0.9979 - val_loss: 1.1973 - val_accuracy: 0.9247
# Epoch 98/100
# 70/70 [==============================] - 36s 515ms/step - loss: 0.0094 - accuracy: 0.9975 - val_loss: 0.8598 - val_accuracy: 0.9422
# Epoch 99/100
# 70/70 [==============================] - 36s 515ms/step - loss: 0.0028 - accuracy: 0.9993 - val_loss: 1.0173 - val_accuracy: 0.9388
# Epoch 100/100
# 70/70 [==============================] - 36s 515ms/step - loss: 0.0130 - accuracy: 0.9969 - val_loss: 1.0407 - val_accuracy: 0.9213

# %% [markdown]
# # STEP 5: MODEL EVALUATION

# %%
score = cnn_model.evaluate(X_test_gray_norm, y_test,verbose=0)
print('Test Accuracy : {:.4f}'.format(score[1]))
# Out:
# Test Accuracy : 0.9165

# %%
score = cnn_model.evaluate(X_test_gray_norm, y_test,verbose=0)
print('Test Loss : {:.4f}'.format(score[0]))
# Out:
# Test Loss : 1.5926

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(accuracy))

plt.plot(epochs, accuracy, 'bo', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation accuracy')
plt.legend()

# %%
plt.plot(epochs, loss, 'ro', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
predicted = cnn_model.predict(X_test_gray_norm)
predicted_classes =np.argmax(predicted,axis=1)
y_true = y_test

# %%
predicted_classes
# Out:
# array([16,  1, 38, ..., 12,  5, 10])

# %%
predicted_classes
# Out:
# array([16,  1, 38, ..., 12,  5, 10])

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, predicted_classes)
plt.figure(figsize = (25,25))
sns.heatmap(cm, annot=True)

# %%
L = 7
W = 7
fig, axes = plt.subplots(L, W, figsize = (12,12))
axes = axes.ravel() # 

for i in np.arange(0, L * W):  
    axes[i].imshow(X_test[i])
    axes[i].set_title("Prediction={}\n True={}".format(predicted_classes[i], y_true[i]))
    axes[i].axis('off')

plt.subplots_adjust(wspace=1)

# %%
cnn_model.save('/content/drive/MyDrive/Project 5/TrafficModel2')
# Out:
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Project 5/TrafficModel2/assets
