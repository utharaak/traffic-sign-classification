# %% [markdown]
# # 18CSC402 Deep Learning
# CB.SC.I5DAS18044
# Uthara Koliyot

# %% [markdown]
# # CODE TO CLASSIFY TRAFFIC SIGNS USING LE-NET ARCHITECTURE IN KERAS

# %% [markdown]
# # PROBLEM STATEMENT

# %% [markdown]
# - In this case study, I am trying to train a Deep Network Model to classify traffic sign images
# - The dataset contains 43 different classes of images.
# - Classes are as listed below:
#
#     - ( 0, b'Speed limit (20km/h)') ( 1, b'Speed limit (30km/h)')
#     - ( 2, b'Speed limit (50km/h)') ( 3, b'Speed limit (60km/h)')
#     - ( 4, b'Speed limit (70km/h)') ( 5, b'Speed limit (80km/h)')
#     - ( 6, b'End of speed limit (80km/h)') ( 7, b'Speed limit (100km/h)')
#     - ( 8, b'Speed limit (120km/h)') ( 9, b'No passing')
#     - (10, b'No passing for vehicles over 3.5 metric tons')
#     - (11, b'Right-of-way at the next intersection') (12, b'Priority road')
#     - (13, b'Yield') (14, b'Stop') (15, b'No vehicles')
#     - (16, b'Vehicles over 3.5 metric tons prohibited') (17, b'No entry')
#     - (18, b'General caution') (19, b'Dangerous curve to the left')
#     - (20, b'Dangerous curve to the right') (21, b'Double curve')
#     - (22, b'Bumpy road') (23, b'Slippery road')
#     - (24, b'Road narrows on the right') (25, b'Road work')
#     - (26, b'Traffic signals') (27, b'Pedestrians') (28, b'Children crossing')
#     - (29, b'Bicycles crossing') (30, b'Beware of ice/snow')
#     - (31, b'Wild animals crossing')
#     - (32, b'End of all speed and passing limits') (33, b'Turn right ahead')
#     - (34, b'Turn left ahead') (35, b'Ahead only') (36, b'Go straight or right')
#     - (37, b'Go straight or left') (38, b'Keep right') (39, b'Keep left')
#     - (40, b'Roundabout mandatory') (41, b'End of no passing')
#     - (42, b'End of no passing by vehicles over 3.5 metric tons')
#
# - The network used is called Le-Net that was presented by Yann LeCun
# http://yann.lecun.com/exdb/publis/pdf/lecun-01a.pdf

# %% [markdown]
# # STEP 1: IMPORT LIBRARIES AND DATASET

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pickle
import seaborn as sns
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt # 
import random

# %%
with open("/content/drive/MyDrive/Project 5/traffic-signs-data/train.p", mode='rb') as training_data:
    train = pickle.load(training_data)
with open("/content/drive/MyDrive/Project 5/traffic-signs-data/valid.p", mode='rb') as validation_data:
    valid = pickle.load(validation_data)
with open("/content/drive/MyDrive/Project 5/traffic-signs-data/test.p", mode='rb') as testing_data:
    test = pickle.load(testing_data)

# %%
X_train, y_train = train['features'], train['labels']
X_validation, y_validation = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %%
X_train.shape
# Out:
# (34799, 32, 32, 3)

# %%
y_train.shape
# Out:
# (34799,)

# %% [markdown]
# # STEP 2: IMAGE EXPLORATION

# %%
i = 1001
plt.imshow(X_train[i]) 
y_train[i]
# Out:
# 36

# %% [markdown]
# # STEP 3: DATA PEPARATION

# %%
## Shuffle the dataset 
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_train, y_train)

# %%
X_train_gray = np.sum(X_train/3, axis=3, keepdims=True)
X_test_gray  = np.sum(X_test/3, axis=3, keepdims=True)
X_validation_gray  = np.sum(X_validation/3, axis=3, keepdims=True)

# %%
X_train_gray_norm = (X_train_gray - 128)/128 
X_test_gray_norm = (X_test_gray - 128)/128
X_validation_gray_norm = (X_validation_gray - 128)/128

# %%
X_train_gray.shape
# Out:
# (34799, 32, 32, 1)

# %%
i = 610
plt.imshow(X_train_gray[i].squeeze(), cmap='gray')
plt.figure()
plt.imshow(X_train[i])

# %% [markdown]
# # STEP 4: MODEL TRAINING

# %% [markdown]
# The model consists of the following layers:
#
# - STEP 1: THE FIRST CONVOLUTIONAL LAYER #1
#     - Input = 32x32x1
#     - Output = 28x28x6
#     - Output = (Input-filter+1)/Stride* => (32-5+1)/1=28
#     - Used a 5x5 Filter with input depth of 3 and output depth of 6
#     - Apply a RELU Activation function to the output
#     - pooling for input, Input = 28x28x6 and Output = 14x14x6
#
#
#
# - STEP 2: THE SECOND CONVOLUTIONAL LAYER #2
#     - Input = 14x14x6
#     - Output = 10x10x16
#     - Layer 2: Convolutional layer with Output = 10x10x16
#     - Output = (Input-filter+1)/strides => 10 = 14-5+1/1
#     - Apply a RELU Activation function to the output
#     - Pooling with Input = 10x10x16 and Output = 5x5x16
#
# - STEP 3: FLATTENING THE NETWORK
#     - Flatten the network with Input = 5x5x16 and Output = 400
#
# - STEP 4: FULLY CONNECTED LAYER
#     - Layer 3: Fully Connected layer with Input = 400 and Output = 120
#     - Apply a RELU Activation function to the output
#
# - STEP 5: ANOTHER FULLY CONNECTED LAYER
#     - Layer 4: Fully Connected Layer with Input = 120 and Output = 84
#     - Apply a RELU Activation function to the output
#
# - STEP 6: FULLY CONNECTED LAYER
#     - Layer 5: Fully Connected layer with Input = 84 and Output = 43

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from keras.callbacks import TensorBoard

from sklearn.model_selection import train_test_split

# %%
image_shape = X_train_gray[i].shape

# %% [markdown]
# # Model 1

# %%
cnn_model = Sequential()

cnn_model.add(Conv2D(filters=6, kernel_size=(5, 5), activation='relu', input_shape=(32,32,1)))
cnn_model.add(AveragePooling2D())

cnn_model.add(Conv2D(filters=16, kernel_size=(5, 5), activation='relu'))
cnn_model.add(AveragePooling2D())

cnn_model.add(Flatten())

cnn_model.add(Dense(units=120, activation='relu'))

cnn_model.add(Dense(units=84, activation='relu'))

cnn_model.add(Dense(units=43, activation = 'softmax'))

# %%
cnn_model.compile(loss ='sparse_categorical_crossentropy', optimizer=Adam(lr=0.001),metrics =['accuracy'])

# %%
history = cnn_model.fit(X_train_gray_norm,
                        y_train,
                        batch_size=500,
                        epochs=50,
                        verbose=1,
                        validation_data = (X_validation_gray_norm,y_validation))
# Out:
# Epoch 1/50
# 70/70 [==============================] - 15s 207ms/step - loss: 3.0640 - accuracy: 0.2038 - val_loss: 2.5347 - val_accuracy: 0.3304
# Epoch 2/50
# 70/70 [==============================] - 15s 208ms/step - loss: 1.5784 - accuracy: 0.5654 - val_loss: 1.3356 - val_accuracy: 0.6050
# Epoch 3/50
# 70/70 [==============================] - 15s 209ms/step - loss: 0.8955 - accuracy: 0.7437 - val_loss: 0.9789 - val_accuracy: 0.7247
# Epoch 4/50
# 70/70 [==============================] - 14s 207ms/step - loss: 0.6324 - accuracy: 0.8238 - val_loss: 0.7715 - val_accuracy: 0.7746
# Epoch 5/50
# 70/70 [==============================] - 15s 208ms/step - loss: 0.4803 - accuracy: 0.8701 - val_loss: 0.6610 - val_accuracy: 0.8068
# Epoch 6/50
# 70/70 [==============================] - 14s 207ms/step - loss: 0.3931 - accuracy: 0.8981 - val_loss: 0.6231 - val_accuracy: 0.8102
# Epoch 7/50
# 70/70 [==============================] - 14s 207ms/step - loss: 0.3387 - accuracy: 0.9112 - val_loss: 0.6021 - val_accuracy: 0.8327
# Epoch 8/50
# 70/70 [==============================] - 15s 208ms/step - loss: 0.2880 - accuracy: 0.9264 - val_loss: 0.6081 - val_accuracy: 0.8311
# Epoch 9/50
# 70/70 [==============================] - 15s 208ms/step - loss: 0.2566 - accuracy: 0.9349 - val_loss: 0.5429 - val_accuracy: 0.8494
# Epoch 10/50
# 70/70 [==============================] - 15s 208ms/step - loss: 0.2225 - accuracy: 0.9451 - val_loss: 0.5322 - val_accuracy: 0.8585
# Epoch 11/50
# 70/70 [==============================] - 15s 208ms/step - loss: 0.2011 - accuracy: 0.9487 - val_loss: 0.5176 - val_accuracy: 0.8630
# Epoch 12/50
# 70/70 [==============================] - 15s 207ms/step - loss: 0.1817 - accuracy: 0.9552 - val_loss: 0.5427 - val_accuracy: 0.8478
# Epoch 13/50
# 70/70 [==============================] - 15s 208ms/step - loss: 0.1625 - accuracy: 0.9595 - val_loss: 0.5151 - val_accuracy: 0.8628
# Epoch 14/50
# 70/70 [==============================] - 14s 207ms/step - loss: 0.1495 - accuracy: 0.9626 - val_loss: 0.5684 - val_accuracy: 0.8435
# Epoch 15/50
# 70/70 [==============================] - 15s 207ms/step - loss: 0.1398 - accuracy: 0.9645 - val_loss: 0.5842 - val_accuracy: 0.8522
# Epoch 16/50
# 70/70 [==============================] - 15s 207ms/step - loss: 0.1249 - accuracy: 0.9691 - val_loss: 0.5487 - val_accuracy: 0.8601
# Epoch 17/50
# 70/70 [==============================] - 15s 209ms/step - loss: 0.1147 - accuracy: 0.9728 - val_loss: 0.5859 - val_accuracy: 0.8562
# Epoch 18/50
# 70/70 [==============================] - 15s 207ms/step - loss: 0.1055 - accuracy: 0.9730 - val_loss: 0.5766 - val_accuracy: 0.8574
# Epoch 19/50
# 70/70 [==============================] - 14s 207ms/step - loss: 0.1045 - accuracy: 0.9730 - val_loss: 0.5546 - val_accuracy: 0.8678
# Epoch 20/50
# 70/70 [==============================] - 14s 206ms/step - loss: 0.0906 - accuracy: 0.9779 - val_loss: 0.5744 - val_accuracy: 0.8664
# Epoch 21/50
# 70/70 [==============================] - 15s 208ms/step - loss: 0.0792 - accuracy: 0.9809 - val_loss: 0.5993 - val_accuracy: 0.8685
# Epoch 22/50
# 70/70 [==============================] - 14s 206ms/step - loss: 0.0781 - accuracy: 0.9804 - val_loss: 0.6441 - val_accuracy: 0.8603
# Epoch 23/50
# 70/70 [==============================] - 14s 207ms/step - loss: 0.0708 - accuracy: 0.9825 - val_loss: 0.6723 - val_accuracy: 0.8621
# Epoch 24/50
# 70/70 [==============================] - 15s 207ms/step - loss: 0.0633 - accuracy: 0.9849 - val_loss: 0.6532 - val_accuracy: 0.8585
# Epoch 25/50
# 70/70 [==============================] - 15s 208ms/step - loss: 0.0623 - accuracy: 0.9839 - val_loss: 0.7006 - val_accuracy: 0.8605
# Epoch 26/50
# 70/70 [==============================] - 15s 207ms/step - loss: 0.0539 - accuracy: 0.9869 - val_loss: 0.6823 - val_accuracy: 0.8535
# Epoch 27/50
# 70/70 [==============================] - 14s 207ms/step - loss: 0.0516 - accuracy: 0.9878 - val_loss: 0.7253 - val_accuracy: 0.8608
# Epoch 28/50
# 70/70 [==============================] - 15s 207ms/step - loss: 0.0452 - accuracy: 0.9893 - val_loss: 0.7411 - val_accuracy: 0.8585
# Epoch 29/50
# 70/70 [==============================] - 14s 206ms/step - loss: 0.0432 - accuracy: 0.9898 - val_loss: 0.7288 - val_accuracy: 0.8703
# Epoch 30/50
# 70/70 [==============================] - 15s 208ms/step - loss: 0.0413 - accuracy: 0.9895 - val_loss: 0.7162 - val_accuracy: 0.8671
# Epoch 31/50
# 70/70 [==============================] - 14s 207ms/step - loss: 0.0424 - accuracy: 0.9894 - val_loss: 0.7327 - val_accuracy: 0.8585
# Epoch 32/50
# 70/70 [==============================] - 15s 208ms/step - loss: 0.0355 - accuracy: 0.9916 - val_loss: 0.7476 - val_accuracy: 0.8608
# Epoch 33/50
# 70/70 [==============================] - 15s 208ms/step - loss: 0.0394 - accuracy: 0.9896 - val_loss: 0.7070 - val_accuracy: 0.8630
# Epoch 34/50
# 70/70 [==============================] - 15s 208ms/step - loss: 0.0319 - accuracy: 0.9921 - val_loss: 0.7374 - val_accuracy: 0.8683
# Epoch 35/50
# 70/70 [==============================] - 14s 207ms/step - loss: 0.0352 - accuracy: 0.9913 - val_loss: 0.7676 - val_accuracy: 0.8696
# Epoch 36/50
# 70/70 [==============================] - 14s 207ms/step - loss: 0.0255 - accuracy: 0.9944 - val_loss: 0.7548 - val_accuracy: 0.8658
# Epoch 37/50
# 70/70 [==============================] - 14s 207ms/step - loss: 0.0277 - accuracy: 0.9932 - val_loss: 0.8110 - val_accuracy: 0.8612
# Epoch 38/50
# 70/70 [==============================] - 15s 207ms/step - loss: 0.0248 - accuracy: 0.9937 - val_loss: 0.9026 - val_accuracy: 0.8585
# Epoch 39/50
# 70/70 [==============================] - 14s 205ms/step - loss: 0.0211 - accuracy: 0.9949 - val_loss: 0.8270 - val_accuracy: 0.8737
# Epoch 40/50
# 70/70 [==============================] - 14s 206ms/step - loss: 0.0199 - accuracy: 0.9951 - val_loss: 0.7763 - val_accuracy: 0.8721
# Epoch 41/50
# 70/70 [==============================] - 14s 206ms/step - loss: 0.0192 - accuracy: 0.9953 - val_loss: 0.8222 - val_accuracy: 0.8653
# Epoch 42/50
# 70/70 [==============================] - 14s 207ms/step - loss: 0.0147 - accuracy: 0.9973 - val_loss: 0.8786 - val_accuracy: 0.8732
# Epoch 43/50
# 70/70 [==============================] - 14s 206ms/step - loss: 0.0159 - accuracy: 0.9962 - val_loss: 0.9715 - val_accuracy: 0.8562
# Epoch 44/50
# 70/70 [==============================] - 14s 207ms/step - loss: 0.0134 - accuracy: 0.9974 - val_loss: 0.9876 - val_accuracy: 0.8569
# Epoch 45/50
# 70/70 [==============================] - 14s 206ms/step - loss: 0.0200 - accuracy: 0.9951 - val_loss: 0.9048 - val_accuracy: 0.8753
# Epoch 46/50
# 70/70 [==============================] - 14s 207ms/step - loss: 0.0178 - accuracy: 0.9954 - val_loss: 1.0353 - val_accuracy: 0.8692
# Epoch 47/50
# 70/70 [==============================] - 14s 206ms/step - loss: 0.0226 - accuracy: 0.9936 - val_loss: 0.8318 - val_accuracy: 0.8848
# Epoch 48/50
# 70/70 [==============================] - 14s 207ms/step - loss: 0.0167 - accuracy: 0.9955 - val_loss: 0.8305 - val_accuracy: 0.8832
# Epoch 49/50
# 70/70 [==============================] - 14s 207ms/step - loss: 0.0153 - accuracy: 0.9956 - val_loss: 0.8230 - val_accuracy: 0.8771
# Epoch 50/50
# 70/70 [==============================] - 14s 206ms/step - loss: 0.0170 - accuracy: 0.9950 - val_loss: 0.8459 - val_accuracy: 0.8748

# %% [markdown]
# # STEP 5: MODEL EVALUATION

# %%
score = cnn_model.evaluate(X_test_gray_norm, y_test,verbose=0)
print('Test Accuracy : {:.4f}'.format(score[1]))
# Out:
# Test Accuracy : 0.8707

# %%
score = cnn_model.evaluate(X_test_gray_norm, y_test,verbose=0)
print('Test Loss : {:.4f}'.format(score[0]))
# Out:
# Test Loss : 1.2412

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(accuracy))

plt.plot(epochs, accuracy, 'bo', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation accuracy')
plt.legend()

# %%
plt.plot(epochs, loss, 'ro', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
predicted = cnn_model.predict(X_test_gray_norm)
predicted_classes =np.argmax(predicted,axis=1)
y_true = y_test

# %%
predicted_classes
# Out:
# array([16,  1, 38, ...,  3,  7, 10])

# %%
predicted_classes
# Out:
# array([16,  1, 38, ...,  3,  7, 10])

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, predicted_classes)
plt.figure(figsize = (25,25))
sns.heatmap(cm, annot=True)

# %%
L = 7
W = 7
fig, axes = plt.subplots(L, W, figsize = (12,12))
axes = axes.ravel() # 

for i in np.arange(0, L * W):  
    axes[i].imshow(X_test[i])
    axes[i].set_title("Prediction={}\n True={}".format(predicted_classes[i], y_true[i]))
    axes[i].axis('off')

plt.subplots_adjust(wspace=1)
